# %% [markdown]
# # **IP Geolocation**

# %%
import ipinfo
def get_ip_details(target):
  access_token = 'XXXXXXXX' # get access_token from: https://ipinfo.io/
  handler = ipinfo.getHandler(access_token)
  details = handler.getDetails(target)
  
  return details.all

# %%
import socket
def get_ip_from_domain_with_socket(domain_name):
  ip_address = socket.gethostbyname(domain_name)
  
  return ip_address

# %%
import nmap
def get_ip_from_domain_with_nmap(domain_name):
    nm = nmap.PortScanner()
    nm.scan(hosts=domain_name, arguments='-sL')
    
    return next((host for host in nm.all_hosts()), "IP address not found")

# %%
from IPython.display import display, Image
def flag(target):
  
  return display(Image(url=target['country_flag_url']))

flag(get_ip_details('149.40.50.217'))
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/US.svg"/>

# %%
import folium
def create_map(target):
        
  latitude, longitude = map(float, target['loc'].split(','))
  m = folium.Map(location=(latitude, longitude), tiles='Esri WorldImagery', zoom_start=14)
  
  flag = f'''<img src="{target['country_flag_url']}" #alt="Flag" style="width:24px;height:16px;">'''
  title = flag + target['country_name'] +', '+ target['city'] +', '+ target['loc']
  
  text = (      
          f"city:<small style='color:#990002'>{target['city']}</small></b><br>"
          f"continent:<small style='color:#990002'>{target['continent']}</small></b><br>"
          f"country:<small style='color:#990002'>{target['country']}</small></b><br>"
          f"country_currency:<small style='color:#990002'>{target['country_currency']}</small></b><br>"
          f"country_flag_url:<small style='color:#990002'>{target['country_flag_url']}</small></b><br>"
          f"country_name:<small style='color:#990002'>{target['country_name']}</small></b><br>"
          f"hostname:<small style='color:#990002'>{target['hostname']}</small></b><br>"
          f"ip:<small style='color:#990002'>{target['ip']}</small></b><br>"
          f"latitude:<small style='color:#990002'>{target['latitude']}</small></b><br>"
          f"loc:<small style='color:#990002'>{target['loc']}</small></b><br>"
          f"longitude:<small style='color:#990002'>{target['longitude']}</small></b><br>"
          f"org:<small style='color:#990002'>{target['org']}</small></b><br>"
          f"postal:<small style='color:#990002'>{target['postal']}</small></b><br>"
          f"region:<small style='color:#990002'>{target['region']}</small></b><br>"
          f"timezone:<small style='color:#990002'>{target['timezone']}</small></b><br>"
          )
  
  m.add_child(folium.LatLngPopup())
  m.get_root().html.add_child(folium.Element(title))
  
  folium.Marker(location=(latitude, longitude), tooltip="Click me!", popup=text, icon=folium.Icon('darkred'), ).add_to(m)
  folium.Circle( location=(latitude, longitude), radius=1000, color="DeepSkyBlue", stroke=False, fill=True, fill_opacity=0.3, opacity=1 ).add_to(m)
  
  m.save(f"maps/{target['city']}_map.html")
  
  display(Image(url=target['country_flag_url'])) 
  
  return m

# %%
get_ip_details('149.40.50.217')
# Out:
# {'ip': '149.40.50.217',
#  'hostname': 'unn-149-40-50-217.datapacket.com',
#  'city': 'Boston',
#  'region': 'Massachusetts',
#  'country': 'US',
#  'loc': '42.3584,-71.0598',
#  'org': 'AS212238 Datacamp Limited',
#  'postal': '02108',
#  'timezone': 'America/New_York',
#  'country_name': 'United States',
#  'isEU': False,
#  'country_flag_url': 'https://cdn.ipinfo.io/static/images/countries-flags/US.svg',
#  'country_flag': {'emoji': '🇺🇸', 'unicode': 'U+1F1FA U+1F1F8'},
#  'country_currency': {'code': 'USD', 'symbol': '$'},
#  'continent': {'code': 'NA', 'name': 'North America'},
#  'latitude': '42.3584',
#  'longitude': '-71.0598'}

# %%
create_map(get_ip_details('104.103.64.0')) # Helsinki
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/FI.svg"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7eda8746851c04dd88c73aeebd9dce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;img src=&quot;https://cdn.ipinfo.io/static/images/countries-flags/FI.svg&quot; #alt=&quot;Flag&quot; style=&quot;width:24px;height:16px;&quot;&gt;Finland, Helsinki, 60.1695,24.9354
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7eda8746851c04dd88c73aeebd9dce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7eda8746851c04dd88c73aeebd9dce8 = L.map(
#                 &quot;map_d7eda8746851c04dd88c73aeebd9dce8&quot;,
#                 {
#                     center: [60.1695, 24.9354],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eea482c1314cb1897b4d058f713a749b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eea482c1314cb1897b4d058f713a749b.addTo(map_d7eda8746851c04dd88c73aeebd9dce8);
#
#
#                 var lat_lng_popup_507785ec2518ce055a0ce870300644b9 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_507785ec2518ce055a0ce870300644b9
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_d7eda8746851c04dd88c73aeebd9dce8);
#                     }
#                 map_d7eda8746851c04dd88c73aeebd9dce8.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_0a0d1645f14cf18dea5ce85d95c1dedd = L.marker(
#                 [60.1695, 24.9354],
#                 {}
#             ).addTo(map_d7eda8746851c04dd88c73aeebd9dce8);
#
#
#             var icon_9afcaf43a0870d9da2e415585fb43700 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a0d1645f14cf18dea5ce85d95c1dedd.setIcon(icon_9afcaf43a0870d9da2e415585fb43700);
#
#
#         var popup_2390f9c9c1232b4a74b247b87a79c788 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20abe231a86179a623587f5bcf2cad4d = $(`&lt;div id=&quot;html_20abe231a86179a623587f5bcf2cad4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;city:&lt;small style=&#x27;color:#990002&#x27;&gt;Helsinki&lt;/small&gt;&lt;/b&gt;&lt;br&gt;continent:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;EU&#x27;, &#x27;name&#x27;: &#x27;Europe&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country:&lt;small style=&#x27;color:#990002&#x27;&gt;FI&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_currency:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;EUR&#x27;, &#x27;symbol&#x27;: &#x27;€&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_flag_url:&lt;small style=&#x27;color:#990002&#x27;&gt;https://cdn.ipinfo.io/static/images/countries-flags/FI.svg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_name:&lt;small style=&#x27;color:#990002&#x27;&gt;Finland&lt;/small&gt;&lt;/b&gt;&lt;br&gt;hostname:&lt;small style=&#x27;color:#990002&#x27;&gt;a104-103-64-0.deploy.static.akamaitechnologies.com&lt;/small&gt;&lt;/b&gt;&lt;br&gt;ip:&lt;small style=&#x27;color:#990002&#x27;&gt;104.103.64.0&lt;/small&gt;&lt;/b&gt;&lt;br&gt;latitude:&lt;small style=&#x27;color:#990002&#x27;&gt;60.1695&lt;/small&gt;&lt;/b&gt;&lt;br&gt;loc:&lt;small style=&#x27;color:#990002&#x27;&gt;60.1695,24.9354&lt;/small&gt;&lt;/b&gt;&lt;br&gt;longitude:&lt;small style=&#x27;color:#990002&#x27;&gt;24.9354&lt;/small&gt;&lt;/b&gt;&lt;br&gt;org:&lt;small style=&#x27;color:#990002&#x27;&gt;AS1299 Arelion Sweden AB&lt;/small&gt;&lt;/b&gt;&lt;br&gt;postal:&lt;small style=&#x27;color:#990002&#x27;&gt;00100&lt;/small&gt;&lt;/b&gt;&lt;br&gt;region:&lt;small style=&#x27;color:#990002&#x27;&gt;Uusimaa&lt;/small&gt;&lt;/b&gt;&lt;br&gt;timezone:&lt;small style=&#x27;color:#990002&#x27;&gt;Europe/Helsinki&lt;/small&gt;&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_2390f9c9c1232b4a74b247b87a79c788.setContent(html_20abe231a86179a623587f5bcf2cad4d);
#
#
#
#         marker_0a0d1645f14cf18dea5ce85d95c1dedd.bindPopup(popup_2390f9c9c1232b4a74b247b87a79c788)
#         ;
#
#
#
#
#             marker_0a0d1645f14cf18dea5ce85d95c1dedd.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_3714f12b7368e8d411dbef170f2fdb37 = L.circle(
#                 [60.1695, 24.9354],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quo

# %%
create_map(get_ip_details('149.40.50.217')) # Boston
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/US.svg"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef6357fa2cc6720c5293bd2a694b8732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;img src=&quot;https://cdn.ipinfo.io/static/images/countries-flags/US.svg&quot; #alt=&quot;Flag&quot; style=&quot;width:24px;height:16px;&quot;&gt;United States, Boston, 42.3584,-71.0598
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef6357fa2cc6720c5293bd2a694b8732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef6357fa2cc6720c5293bd2a694b8732 = L.map(
#                 &quot;map_ef6357fa2cc6720c5293bd2a694b8732&quot;,
#                 {
#                     center: [42.3584, -71.0598],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de65a061ccd5d28c98ab24ed68a51e2b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_de65a061ccd5d28c98ab24ed68a51e2b.addTo(map_ef6357fa2cc6720c5293bd2a694b8732);
#
#
#                 var lat_lng_popup_cfc0823495d20dd28ba1dea7c4875ea0 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_cfc0823495d20dd28ba1dea7c4875ea0
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_ef6357fa2cc6720c5293bd2a694b8732);
#                     }
#                 map_ef6357fa2cc6720c5293bd2a694b8732.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_3c3554692bd1d10b5558a832547273ef = L.marker(
#                 [42.3584, -71.0598],
#                 {}
#             ).addTo(map_ef6357fa2cc6720c5293bd2a694b8732);
#
#
#             var icon_f66feb36d244712b37f1ecd05b1c2bf0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c3554692bd1d10b5558a832547273ef.setIcon(icon_f66feb36d244712b37f1ecd05b1c2bf0);
#
#
#         var popup_f31dc03ee09c406e4ccd84713fe63ad2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c62305a1c7e08161a8626086b1503096 = $(`&lt;div id=&quot;html_c62305a1c7e08161a8626086b1503096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;city:&lt;small style=&#x27;color:#990002&#x27;&gt;Boston&lt;/small&gt;&lt;/b&gt;&lt;br&gt;continent:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;NA&#x27;, &#x27;name&#x27;: &#x27;North America&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country:&lt;small style=&#x27;color:#990002&#x27;&gt;US&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_currency:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;USD&#x27;, &#x27;symbol&#x27;: &#x27;$&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_flag_url:&lt;small style=&#x27;color:#990002&#x27;&gt;https://cdn.ipinfo.io/static/images/countries-flags/US.svg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_name:&lt;small style=&#x27;color:#990002&#x27;&gt;United States&lt;/small&gt;&lt;/b&gt;&lt;br&gt;hostname:&lt;small style=&#x27;color:#990002&#x27;&gt;unn-149-40-50-217.datapacket.com&lt;/small&gt;&lt;/b&gt;&lt;br&gt;ip:&lt;small style=&#x27;color:#990002&#x27;&gt;149.40.50.217&lt;/small&gt;&lt;/b&gt;&lt;br&gt;latitude:&lt;small style=&#x27;color:#990002&#x27;&gt;42.3584&lt;/small&gt;&lt;/b&gt;&lt;br&gt;loc:&lt;small style=&#x27;color:#990002&#x27;&gt;42.3584,-71.0598&lt;/small&gt;&lt;/b&gt;&lt;br&gt;longitude:&lt;small style=&#x27;color:#990002&#x27;&gt;-71.0598&lt;/small&gt;&lt;/b&gt;&lt;br&gt;org:&lt;small style=&#x27;color:#990002&#x27;&gt;AS212238 Datacamp Limited&lt;/small&gt;&lt;/b&gt;&lt;br&gt;postal:&lt;small style=&#x27;color:#990002&#x27;&gt;02108&lt;/small&gt;&lt;/b&gt;&lt;br&gt;region:&lt;small style=&#x27;color:#990002&#x27;&gt;Massachusetts&lt;/small&gt;&lt;/b&gt;&lt;br&gt;timezone:&lt;small style=&#x27;color:#990002&#x27;&gt;America/New_York&lt;/small&gt;&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_f31dc03ee09c406e4ccd84713fe63ad2.setContent(html_c62305a1c7e08161a8626086b1503096);
#
#
#
#         marker_3c3554692bd1d10b5558a832547273ef.bindPopup(popup_f31dc03ee09c406e4ccd84713fe63ad2)
#         ;
#
#
#
#
#             marker_3c3554692bd1d10b5558a832547273ef.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_8ead5228e8a85f61da440765802afb2a = L.circle(
#                 [42.3584, -71.0598],
#                 {&quot;bubblingMouseEvents&quot;: true, &qu

# %%
create_map(get_ip_details('46.36.36.125')) # Prague
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/CZ.svg"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0297a1ca7924a5bad969df8e88fd90c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;img src=&quot;https://cdn.ipinfo.io/static/images/countries-flags/CZ.svg&quot; #alt=&quot;Flag&quot; style=&quot;width:24px;height:16px;&quot;&gt;Czech Republic, Prague, 50.0880,14.4208
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0297a1ca7924a5bad969df8e88fd90c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0297a1ca7924a5bad969df8e88fd90c1 = L.map(
#                 &quot;map_0297a1ca7924a5bad969df8e88fd90c1&quot;,
#                 {
#                     center: [50.088, 14.4208],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeb55c79007d89144acf83d9a9ecbd75 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eeb55c79007d89144acf83d9a9ecbd75.addTo(map_0297a1ca7924a5bad969df8e88fd90c1);
#
#
#                 var lat_lng_popup_9a23dd57c83e6feb34f8f2223af78255 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_9a23dd57c83e6feb34f8f2223af78255
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_0297a1ca7924a5bad969df8e88fd90c1);
#                     }
#                 map_0297a1ca7924a5bad969df8e88fd90c1.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_47dd552c64736045f509c9c25545b0ff = L.marker(
#                 [50.088, 14.4208],
#                 {}
#             ).addTo(map_0297a1ca7924a5bad969df8e88fd90c1);
#
#
#             var icon_052a8042fb5027b5147b122af667c4d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47dd552c64736045f509c9c25545b0ff.setIcon(icon_052a8042fb5027b5147b122af667c4d0);
#
#
#         var popup_2f479ed33778f7b5c9e224f9be0d9ac2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_676f023d47723a6648779f43272f90b2 = $(`&lt;div id=&quot;html_676f023d47723a6648779f43272f90b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;city:&lt;small style=&#x27;color:#990002&#x27;&gt;Prague&lt;/small&gt;&lt;/b&gt;&lt;br&gt;continent:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;EU&#x27;, &#x27;name&#x27;: &#x27;Europe&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country:&lt;small style=&#x27;color:#990002&#x27;&gt;CZ&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_currency:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;CZK&#x27;, &#x27;symbol&#x27;: &#x27;Kč&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_flag_url:&lt;small style=&#x27;color:#990002&#x27;&gt;https://cdn.ipinfo.io/static/images/countries-flags/CZ.svg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_name:&lt;small style=&#x27;color:#990002&#x27;&gt;Czech Republic&lt;/small&gt;&lt;/b&gt;&lt;br&gt;hostname:&lt;small style=&#x27;color:#990002&#x27;&gt;cleopatra.tor.foundation&lt;/small&gt;&lt;/b&gt;&lt;br&gt;ip:&lt;small style=&#x27;color:#990002&#x27;&gt;46.36.36.125&lt;/small&gt;&lt;/b&gt;&lt;br&gt;latitude:&lt;small style=&#x27;color:#990002&#x27;&gt;50.0880&lt;/small&gt;&lt;/b&gt;&lt;br&gt;loc:&lt;small style=&#x27;color:#990002&#x27;&gt;50.0880,14.4208&lt;/small&gt;&lt;/b&gt;&lt;br&gt;longitude:&lt;small style=&#x27;color:#990002&#x27;&gt;14.4208&lt;/small&gt;&lt;/b&gt;&lt;br&gt;org:&lt;small style=&#x27;color:#990002&#x27;&gt;AS42422 SecurityNet.cz s.r.o.&lt;/small&gt;&lt;/b&gt;&lt;br&gt;postal:&lt;small style=&#x27;color:#990002&#x27;&gt;110 00&lt;/small&gt;&lt;/b&gt;&lt;br&gt;region:&lt;small style=&#x27;color:#990002&#x27;&gt;Prague&lt;/small&gt;&lt;/b&gt;&lt;br&gt;timezone:&lt;small style=&#x27;color:#990002&#x27;&gt;Europe/Prague&lt;/small&gt;&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_2f479ed33778f7b5c9e224f9be0d9ac2.setContent(html_676f023d47723a6648779f43272f90b2);
#
#
#
#         marker_47dd552c64736045f509c9c25545b0ff.bindPopup(popup_2f479ed33778f7b5c9e224f9be0d9ac2)
#         ;
#
#
#
#
#             marker_47dd552c64736045f509c9c25545b0ff.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_f8a61a650648ec9cd08df7b19dbf3006 = L.circle(
#                 [50.088, 14.4208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;DeepS

# %%
create_map(get_ip_details('185.207.104.170')) # Nürnberg
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/DE.svg"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a62606c539e53adb30f25abdadce23d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;img src=&quot;https://cdn.ipinfo.io/static/images/countries-flags/DE.svg&quot; #alt=&quot;Flag&quot; style=&quot;width:24px;height:16px;&quot;&gt;Germany, Nürnberg, 49.4453,11.0222
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a62606c539e53adb30f25abdadce23d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a62606c539e53adb30f25abdadce23d = L.map(
#                 &quot;map_4a62606c539e53adb30f25abdadce23d&quot;,
#                 {
#                     center: [49.4453, 11.0222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9865b94889a0ab7ca5a71dd2c62a6c68 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9865b94889a0ab7ca5a71dd2c62a6c68.addTo(map_4a62606c539e53adb30f25abdadce23d);
#
#
#                 var lat_lng_popup_b31aa14dfdb969b8a35e71f31d92b621 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_b31aa14dfdb969b8a35e71f31d92b621
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_4a62606c539e53adb30f25abdadce23d);
#                     }
#                 map_4a62606c539e53adb30f25abdadce23d.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_be486627a757e74ff6d745efc06bfd28 = L.marker(
#                 [49.4453, 11.0222],
#                 {}
#             ).addTo(map_4a62606c539e53adb30f25abdadce23d);
#
#
#             var icon_4d37a7eda3aeb0707a14310250539401 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be486627a757e74ff6d745efc06bfd28.setIcon(icon_4d37a7eda3aeb0707a14310250539401);
#
#
#         var popup_c5c42be6ba0355c39cc989cd26c21006 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0ab389b50081c1b4ee5f267897301f4 = $(`&lt;div id=&quot;html_d0ab389b50081c1b4ee5f267897301f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;city:&lt;small style=&#x27;color:#990002&#x27;&gt;Nürnberg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;continent:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;EU&#x27;, &#x27;name&#x27;: &#x27;Europe&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country:&lt;small style=&#x27;color:#990002&#x27;&gt;DE&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_currency:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;EUR&#x27;, &#x27;symbol&#x27;: &#x27;€&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_flag_url:&lt;small style=&#x27;color:#990002&#x27;&gt;https://cdn.ipinfo.io/static/images/countries-flags/DE.svg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_name:&lt;small style=&#x27;color:#990002&#x27;&gt;Germany&lt;/small&gt;&lt;/b&gt;&lt;br&gt;hostname:&lt;small style=&#x27;color:#990002&#x27;&gt;mail.ip7.eu&lt;/small&gt;&lt;/b&gt;&lt;br&gt;ip:&lt;small style=&#x27;color:#990002&#x27;&gt;185.207.104.170&lt;/small&gt;&lt;/b&gt;&lt;br&gt;latitude:&lt;small style=&#x27;color:#990002&#x27;&gt;49.4453&lt;/small&gt;&lt;/b&gt;&lt;br&gt;loc:&lt;small style=&#x27;color:#990002&#x27;&gt;49.4453,11.0222&lt;/small&gt;&lt;/b&gt;&lt;br&gt;longitude:&lt;small style=&#x27;color:#990002&#x27;&gt;11.0222&lt;/small&gt;&lt;/b&gt;&lt;br&gt;org:&lt;small style=&#x27;color:#990002&#x27;&gt;AS197540 netcup GmbH&lt;/small&gt;&lt;/b&gt;&lt;br&gt;postal:&lt;small style=&#x27;color:#990002&#x27;&gt;90431&lt;/small&gt;&lt;/b&gt;&lt;br&gt;region:&lt;small style=&#x27;color:#990002&#x27;&gt;Bavaria&lt;/small&gt;&lt;/b&gt;&lt;br&gt;timezone:&lt;small style=&#x27;color:#990002&#x27;&gt;Europe/Berlin&lt;/small&gt;&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_c5c42be6ba0355c39cc989cd26c21006.setContent(html_d0ab389b50081c1b4ee5f267897301f4);
#
#
#
#         marker_be486627a757e74ff6d745efc06bfd28.bindPopup(popup_c5c42be6ba0355c39cc989cd26c21006)
#         ;
#
#
#
#
#             marker_be486627a757e74ff6d745efc06bfd28.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_aaf5dde1435c9f7e0eb8228c17980922 = L.circle(
#                 [49.4453, 11.0222],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;DeepSkyBlue&quot;, &quot;dashArr

# %%
get_ip_from_domain_with_nmap('scanme.nmap.org')
# Out:
# '45.33.32.156'

# %%
create_map(get_ip_details(get_ip_from_domain_with_socket('scanme.nmap.org')))
# Out:
# <img src="https://cdn.ipinfo.io/static/images/countries-flags/US.svg"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9489dcef650f7b6dca89a187c6d264f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;img src=&quot;https://cdn.ipinfo.io/static/images/countries-flags/US.svg&quot; #alt=&quot;Flag&quot; style=&quot;width:24px;height:16px;&quot;&gt;United States, Fremont, 37.5483,-121.9886
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9489dcef650f7b6dca89a187c6d264f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9489dcef650f7b6dca89a187c6d264f2 = L.map(
#                 &quot;map_9489dcef650f7b6dca89a187c6d264f2&quot;,
#                 {
#                     center: [37.5483, -121.9886],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80c481724dd0c71a92660a4ca74be915 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_80c481724dd0c71a92660a4ca74be915.addTo(map_9489dcef650f7b6dca89a187c6d264f2);
#
#
#                 var lat_lng_popup_46790b59f4a98febaaea29b5885122da = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_46790b59f4a98febaaea29b5885122da
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_9489dcef650f7b6dca89a187c6d264f2);
#                     }
#                 map_9489dcef650f7b6dca89a187c6d264f2.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_9131c790bebc4931a56e4619be805aa4 = L.marker(
#                 [37.5483, -121.9886],
#                 {}
#             ).addTo(map_9489dcef650f7b6dca89a187c6d264f2);
#
#
#             var icon_95d4fb3cd18623d371dc7ee31bfeaee6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9131c790bebc4931a56e4619be805aa4.setIcon(icon_95d4fb3cd18623d371dc7ee31bfeaee6);
#
#
#         var popup_44ef830463c163f3d88f90355917950e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fd10d56af1b2ef94dd63a3101a28ed2 = $(`&lt;div id=&quot;html_7fd10d56af1b2ef94dd63a3101a28ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;city:&lt;small style=&#x27;color:#990002&#x27;&gt;Fremont&lt;/small&gt;&lt;/b&gt;&lt;br&gt;continent:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;NA&#x27;, &#x27;name&#x27;: &#x27;North America&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country:&lt;small style=&#x27;color:#990002&#x27;&gt;US&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_currency:&lt;small style=&#x27;color:#990002&#x27;&gt;{&#x27;code&#x27;: &#x27;USD&#x27;, &#x27;symbol&#x27;: &#x27;$&#x27;}&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_flag_url:&lt;small style=&#x27;color:#990002&#x27;&gt;https://cdn.ipinfo.io/static/images/countries-flags/US.svg&lt;/small&gt;&lt;/b&gt;&lt;br&gt;country_name:&lt;small style=&#x27;color:#990002&#x27;&gt;United States&lt;/small&gt;&lt;/b&gt;&lt;br&gt;hostname:&lt;small style=&#x27;color:#990002&#x27;&gt;scanme.nmap.org&lt;/small&gt;&lt;/b&gt;&lt;br&gt;ip:&lt;small style=&#x27;color:#990002&#x27;&gt;45.33.32.156&lt;/small&gt;&lt;/b&gt;&lt;br&gt;latitude:&lt;small style=&#x27;color:#990002&#x27;&gt;37.5483&lt;/small&gt;&lt;/b&gt;&lt;br&gt;loc:&lt;small style=&#x27;color:#990002&#x27;&gt;37.5483,-121.9886&lt;/small&gt;&lt;/b&gt;&lt;br&gt;longitude:&lt;small style=&#x27;color:#990002&#x27;&gt;-121.9886&lt;/small&gt;&lt;/b&gt;&lt;br&gt;org:&lt;small style=&#x27;color:#990002&#x27;&gt;AS63949 Akamai Connected Cloud&lt;/small&gt;&lt;/b&gt;&lt;br&gt;postal:&lt;small style=&#x27;color:#990002&#x27;&gt;94536&lt;/small&gt;&lt;/b&gt;&lt;br&gt;region:&lt;small style=&#x27;color:#990002&#x27;&gt;California&lt;/small&gt;&lt;/b&gt;&lt;br&gt;timezone:&lt;small style=&#x27;color:#990002&#x27;&gt;America/Los_Angeles&lt;/small&gt;&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_44ef830463c163f3d88f90355917950e.setContent(html_7fd10d56af1b2ef94dd63a3101a28ed2);
#
#
#
#         marker_9131c790bebc4931a56e4619be805aa4.bindPopup(popup_44ef830463c163f3d88f90355917950e)
#         ;
#
#
#
#
#             marker_9131c790bebc4931a56e4619be805aa4.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_fd616dea6b38a12402d1182d89aeed65 = L.circle(
#                 [37.5483, -121.9886],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;co
